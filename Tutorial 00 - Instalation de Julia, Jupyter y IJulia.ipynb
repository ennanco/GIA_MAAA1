# %% [markdown]
# # Lenguajes para Machine Learning
#
# Para la implementación de los ejercicios prácticos, existen varias opciones en cuanto a lenguaje de programación. Entre las muchas opciones disponibles, se han considerado tres posibilidades:
#
# * **Matlab**. Es un lenguaje científico con muchos años de experiencia, por lo que tiene la ventaja de contar con una gran cantidad de módulos (llamados Toolboxes) para casi cualquier operación que se desee realizar, junto con una excelente documentación. Esto lo convierte en un lenguaje muy adecuado para iniciarse y aprender. Sin embargo, su principal desventaja es que es necesario adquirir una licencia para utilizarlo. Este requisito ha hecho que muchas empresas no opten por esta opción, por lo que en la práctica no es tan utilizado como Python en el ámbito empresarial.
#
# * **Python**. Sin duda es el más utilizado. Es un lenguaje moderno, sencillo, con una gran cantidad de módulos y abundante documentación, aunque sin llegar al número o calidad de Matlab. Es gratuito y de código abierto, y de propósito general, lo que lo ha convertido en uno de los lenguajes más usados en el mundo empresarial hoy en día. Además, una de las primeras librerías de Deep Learning, llamada TensorFlow, fue desarrollada por Google para este lenguaje, lo que ha aumentado drásticamente la comunidad de desarrolladores de aplicaciones de aprendizaje automático en este lenguaje. Además, bibliotecas como Scikit-Learn también permiten el uso de otras técnicas de aprendizaje automático como árboles de decisión o máquinas de soporte vectorial. El mayor problema de este lenguaje es que no es un lenguaje científico sino de propósito general, y la programación vectorial no está soportada de forma nativa, sino a través de la librería numpy, lo que conlleva una considerable pérdida de rendimiento.
#
# * **Julia**. Es un lenguaje emergente, de vida muy corta y completamente científico, desarrollado en el Instituto Tecnológico de Massachusetts (MIT). Su primera versión estable es de hace solo unos pocos años, y actualmente se encuentra en pleno desarrollo. Por esta razón, no cuenta con el mismo número de módulos que Matlab o Python, aunque el número de módulos crece rápidamente, ya que el lenguaje es gratuito y de código abierto. Este lenguaje ha sido desarrollado como un punto intermedio entre Matlab, como lenguaje científico, y Python, como lenguaje sencillo y de código abierto, con una velocidad de ejecución superior a ambos. Sus principales inconvenientes son que la comunidad de desarrolladores no es tan grande como la de Python, y el número de módulos no es tan amplio como el de Matlab, y, dado su corto periodo de vida, aún no se ha hecho presente en el mundo empresarial.
#
# ## ¿Por qué usar Julia en esta asignatura?
# Como se ha indicado, es un lenguaje que todavía no tiene una gran presencia a nivel empresarial. Sin embargo, esto se mitiga por tres factores importantes:
#
# * Dado que se han adquirido habilidades en el lenguaje Python en otras asignaturas, esta asignatura brinda la oportunidad de aprender un lenguaje científico que completa los conocimientos.
#
# * Varias de las instituciones más prestigiosas del mundo, como Berkeley, Stanford o MIT, recomiendan y enseñan esta asignatura en este lenguaje debido al control que ofrece a la hora de investigar o implementar detalles sin perder rendimiento. Esto casi garantiza que en un corto periodo de tiempo comenzará a verse a nivel empresarial.
#
# * Aunque Python es el lenguaje más utilizado a nivel empresarial, esto se debe fundamentalmente al uso de la librería `Scikit-Learn`.Julia cuenta con una interfaz (`ScikitLearn.jl`) que permite acceder a modelos de scikit-learn, pero actualmente se recomienda utilizar librerías nativas como `MLJ.jl`, `Flux.jl`, `DecisionTree.jl` o `LIBSVM.jl` para evitar dependencias externas. Aun así, se podría usar como parte del aprendizaje de esta materia, y su traslado a una empresa en Python no tendría mayor dificultadsin dificultad, ya que tendrían conocimientos tanto de la librería como del lenguaje.
#
# ## Pasos para la instalación de Julia
#
# La instalación de Julia es bastante sencilla, ya sea utilizando binarios precompilados o compilando desde el código fuente. Descarga e instala Julia siguiendo las instrucciones en [https://julialang.org/downloads/].
#
# > ⚠️ **Usuarios de Mac más antiguos**: La instalación de Julia puede ser problemática debido a compiladores obsoletos. En caso de errores durante la instalación, podría valer la pena intentar instalarlo a través de [MacPorts](https://ports.macports.org/port/julia/). Tras la [instalación de MacPorts](https://www.macports.org/install.php/), Julia se puede instalar con `sudo port install julia`.
#
# También podría ser útil instalar Jupyter en un entorno local para realizar algunas pruebas. Esto se puede hacer ejecutando el siguiente comando, si aún no lo tienes instalado.

# %% [markdown]
# Para ejecutarse en la terminal si es necesario, antes de ejecutar cualquier código aquí:
# ```bash
#         pip install notebook
# ```

# %% [markdown]
# Después de esa instalación, puedes proceder a instalar el kernel de Julia para Jupyter Notebook. Simplemente abre una terminal y escribe `julia`. Deberías ver el siguiente entorno:
#
# ![Imagen de inicio de Julia en la terminal](./img/JuliaTerminal.png "Terminal de Julia")

# %% [markdown]
# Para añadir soporte para notebooks, debes ejecutar las siguientes líneas, las cuales cubriremos con más detalle en las siguientes secciones.

# %% [markdown]
# ```julia
#     using Pkg
#     Pkg.add("IJulia")
#
# ```

# %% [markdown]
# Estas líneas están cargando el paquete `Pkg`, que se utiliza para gestionar paquetes en Julia, y estamos añadiendo el paquete `IJulia`. Ahora puedes ejecutar comandos y crear un notebook en Julia dentro de Jupyter Notebooks. El siguiente paso es ejecutar el comando:
# ```bash
#     jupyter notebook
#
# Después de eso, puedes acceder a la dirección URL y crear nuevos notebooks en Python y Julia, o en ambos.

# %% [markdown]
# ## Sintaxis básica en Julia
#
# Esta sección mostrará algunas operaciones típicas con un doble objetivo: primero, servir como una referencia rápida (cheatsheet), y segundo, asegurar que la configuración previa está funcionando correctamente. Muchos de los ejemplos están basados en este [tutorial](https://learnxinyminutes.com/docs/julia/), que puede ser utilizado como referencia adicional.

# %% [markdown]
# ### Tipos de números
#
# En Julia, hay varios tipos de números. Aunque durante la primera práctica profundizaremos en esta cuestión, aquí hay algunos ejemplos de diferentes definiciones.

# %%
typeof(2)

# %%
typeof(4.0)

# %%
typeof(1 + 1im)

# %%
typeof(2 // 3)

# %%
supertype(AbstractFloat)

# %%
supertype(Real)

# %%
supertype(Number)

# %% [markdown]
# ### Operadores Booleanos
#
# Ten en cuenta que la negación se realiza con `!`.

# %%
(1==1) & !(1!=1)

# %% [markdown]
# ### Strings

# %%
typeof("This is a string")

# %%
typeof('a') != typeof("a") # the single quote is only for caracters

# %%
using Printf
Printf.@printf "%d is less than %f" 4.5 5.3

# %%
println("This is in Julia - $(VERSION)")

# %% [markdown]
# ### Variable
#
# Los nombres de las variables deben comenzar con una letra, pero después de eso, puedes usar letras, dígitos, guiones bajos y signos de exclamación.

# %%
xMarksTheSpot2Dig! = 1

# %%
a = Int64[]

# %%
push!(a, 1)

# %%
push!(a, 2)

# %%
b = [3, 4, 5]

# %%
b[1]

# %%
b[end]

# %%
append!(a, b)

# %%
pop!(a)

# %%
a[2:3]

# %%
4 in a

# %%
length(a)

# %% [markdown]
# ### Tuplas

# %%
a = (1, 5, 3)
typeof(a)

# %%
a[2]

# %%
a, b, c = (1, 2, 3)

# %%
println(" First element is $(a), Second is $(b), and last is $(c)")

# %%
n = (x=1, y=2, z=3) # use keyword assignments in a tuple to create a NamedTuple

# %%
println(" First element is $(n.x), Second is $(n.y), and last is $(n.z)")

# %% [markdown]
# ### Diccionarios

# %%
d = Dict("one"=>1, "two"=>2, "three"=>3)

# %%
d["one"]

# %%
keys(d)

# %%
values(d)

# %%
haskey(d, "one")

# %% [markdown]
# ### Control de Flujo

# %%
condition_var = 5

# if-then=else
# Indentation is not meaningful in Julia.

if condition_var > 10
    println("If branch is mandatory")
elseif condition_var < 10    
    println("Elseif branch is optional")
else                    
    println("The else branch os also optional")
end

# %%
# The for loop can work on iterables
for animal in ["dog", "cat", "mouse"]
    println("$animal is a mammal")
    # You can use $ to interpolate variables or expression into strings
end

# %%
for (k,v) in Dict("dog"=>"mammal","cat"=>"mammal","mouse"=>"mammal")
    println("$k is a $v")
end

# %%
# The while loop
x = 0
while x < 4
    global x # be aware that the variable which is changed is the global one
    println(x)
    x += 1  # Shorthand for x = x + 1
end

# %% [markdown]
# ### Funciones

# %%
# You can define a function with or without defatult values
function defaults(a, b, x=5, y=6)
    return "$a $b and $x $y"
end

# %%
defaults('h', 'g', 'j')  # => "h g and j 6"

# %%
try
    defaults('h')  # => ERROR: MethodError: no method matching defaults(::Char)
catch e
    println(e)
end

# %%
function all_the_args(normalArg, optionalPositionalArg=2; keywordArg="foo")
    println("normal arg: $normalArg")
    println("optional arg: $optionalPositionalArg")
    println("keyword arg: $keywordArg")
end

all_the_args("normal")

# %%
# Lambda expressions
(x -> x+1)(3)

# %%
# Julia has first class functions
function create_adder(x)
    adder = function (y)
        return x + y
    end
    return adder
end

# %%
# This function is identical to create_adder implementation above.
function create_adder(x)
    y -> x + y
end

# %%
# You can also name the internal function, if you want
function create_adder(x)
    function adder(y)
        x + y
    end
    adder
end

# %%
f = create_adder(10)
map(f, [1,2,3])

# %%
filter(x -> x > 5, [3, 4, 5, 6, 7])

# %%
[f(i) for i in [1, 2, 3]]

# %% [markdown]
# ### Typos compuestos
# Julia soporta la definición de nuevos tipos en una jerarquía que permite la herencia de métodos y propiedades. También permitirá el despacho múltiple.

# %%
abstract type Cat end # just a name and point in the type hierarchy
subtypes(Cat)

# %%
# <: is the subtyping operator
struct Lion <: Cat # Lion is a subtype of Cat
    mane_color
    roar::String
end

struct Panther <: Cat # Panther is also a subtype of Cat
  eye_color
  Panther() = new("green")
  # Panthers will only have this constructor, and no default constructor.
end

# Also it is not required to inheritance anything
struct Tiger
  taillength::Float64
  coatcolor # not including a type annotation is the same as `::Any`
end

subtypes(Cat)

# %%
function voice(animal::Lion)
  animal.roar # access type properties using dot notation
end

function voice(animal::Panther)
  "grrr"
end

function voice(animal::Tiger)
  "rawwwr"
end

# %%
println("The Tiger says $(voice(Tiger(3.5,"orange")))")
println("The Lion says $(voice(Lion("brown","ROAAAR")))")
println("The Lion says $(voice(Panther()))")

# %% [markdown]
# ### Código Nativo

# %%
Add(x, y) = x + y
# Out:
# Add (generic function with 1 method)

# %%
Add(4,5)
# Out:
# 9

# %%
code_native(Add, (Int32,Int32), syntax = :intel)
# Out:
# 	.text
# 	.file	"Add"
# 	.globl	julia_Add_801                   # -- Begin function julia_Add_801
# 	.p2align	4, 0x90
# 	.type	julia_Add_801,@function
# julia_Add_801:                          # @julia_Add_801
# ; ┌ @ In[1]:1 within `Add`
# # %bb.0:                                # %top
# 	push	rbp
# 	mov	rbp, rsp
#                                         # kill: def $esi killed $esi def $rsi
#                                         # kill: def $edi killed $edi def $rdi
# ; │┌ @ int.jl:87 within `+`
# 	lea	eax, [rdi + rsi]
# ; │└
# 	pop	rbp
# 	ret
# .Lfunc_end0:
# 	.size	julia_Add_801, .Lfunc_end0-julia_Add_801
# ; └
#                                         # -- End function
# 	.section	".note.GNU-stack","",@progbits

# %%
code_native(Add, (Float32,Float32), syntax = :intel)
# Out:
# 	.text
# 	.file	"Add"
# 	.globl	julia_Add_826                   # -- Begin function julia_Add_826
# 	.p2align	4, 0x90
# 	.type	julia_Add_826,@function
# julia_Add_826:                          # @julia_Add_826
# ; ┌ @ In[1]:1 within `Add`
# # %bb.0:                                # %top
# 	push	rbp
# 	mov	rbp, rsp
# ; │┌ @ float.jl:409 within `+`
# 	vaddss	xmm0, xmm0, xmm1
# ; │└
# 	pop	rbp
# 	ret
# .Lfunc_end0:
# 	.size	julia_Add_826, .Lfunc_end0-julia_Add_826
# ; └
#                                         # -- End function
# 	.section	".note.GNU-stack","",@progbits

# %%
code_llvm(Add, (Int32,Int32))
# Out:
# ;  @ In[1]:1 within `Add`
# define i32 @julia_Add_858(i32 signext %0, i32 signext %1) #0 {
# top:
# ; ┌ @ int.jl:87 within `+`
#    %2 = add i32 %1, %0
# ; └
#   ret i32 %2
# }

# %% [markdown]
# ## Entornos de Julia
#
# ### ¿Qué es un entorno (o proyecto) de Julia?
#
# En Julia, un **entorno** (también llamado comúnmente un **proyecto**) es un espacio de trabajo que define su propio conjunto de paquetes y versiones.
# Esto garantiza que tu código se ejecute con las dependencias exactas que especifiques — de manera independiente a lo que esté instalado globalmente o en otros proyectos.
#
# Si estás familiarizado con **Python**, esto es muy similar a usar `venv`, `conda` o `poetry`.
# En **R**, se parece a usar `renv` o `packrat`.
#
# Los entornos en Julia se definen mediante dos archivos clave:
#
# - `Project.toml`: lista tus dependencias directas.
# - `Manifest.toml`: registra las versiones exactas de todos los paquetes (incluidas las dependencias transitivas).
#
# > 📁 Cualquier carpeta que contenga un `Project.toml` se considera un **proyecto de Julia**.
#
# ```
#  my_project/
#  ├── Project.toml
#  ├── Manifest.toml
#  └── notebook.ipynb
# ```
#
#
# ---
#
# ### 🔄 Comparación con otros ecosistemas
#
# | Característica            | **Julia**                          | **Python**                          | **R**                          |
# |----------------------------|------------------------------------|-------------------------------------|--------------------------------|
# | Nombre del entorno         | Entorno / Proyecto                 | Entorno virtual (`venv`, `conda`)   | Proyecto / entorno renv        |
# | Archivo de dependencias    | `Project.toml`                     | `requirements.txt` / `pyproject.toml` | `renv.lock` / `DESCRIPTION`   |
# | Archivo de bloqueo completo | `Manifest.toml`                   | `poetry.lock` / `Pipfile.lock`      | `renv.lock` / `.Rprofile`     |
# | Activación                 | `Pkg.activate("path")`             | `source venv/bin/activate` o `conda activate` | `renv::activate()`         |
# | Instalación de paquetes    | `Pkg.add("PkgName")`               | `pip install PkgName`               | `install.packages("PkgName")` |
# | Aislamiento                | ✔ Por proyecto                     | ✔ Por virtualenv/conda              | ✔ Por proyecto                |
#
# ---
#
# Usar entornos es esencial para:
#
# - Mantener las dependencias organizadas y aisladas
# - Reproducir tus resultados
# - Colaborar de forma segura entre distintas máquinas o compañeros de equipo
#
# En las siguientes secciones, aprenderás cómo crear y activar un entorno de Julia para tus notebooks.

# %% [markdown]
# ### ¿Por qué usar entornos en Julia?
#
# En Julia, gestionar las dependencias correctamente es esencial para evitar conflictos de versiones y garantizar la reproducibilidad.
#
# Por defecto, cuando instalas un paquete, este se añade a tu **entorno global**, que se comparte entre todos los proyectos.
# Esto puede generar incompatibilidades cuando distintos proyectos requieren versiones diferentes del mismo paquete.
#
# La solución recomendada es usar **entornos específicos por proyecto**, que aíslan las dependencias por notebook o aplicación.
#
# ### Creación de un nuevo proyecto
#
# Puedes crear un nuevo entorno abriendo Julia y ejecutando lo siguiente en el REPL:
#
# ```julia
# ] activate .
# ] instantiate
#
# ```
# * `activate .` le indica a Julia que cree o active un proyecto en la carpeta actual.
#
# * Si no existe un `Project.toml`, se creará automáticamente.
#
# * `instantiate` instala los paquetes listados en Project.toml y Manifest.toml.
#
# 📝 Es una buena práctica ejecutar tus notebooks dentro de una carpeta de este tipo y activar el entorno al comienzo del notebook..
#
# ### Activar entornos en notebooks de Jupyter
#
# Al inicio de tu notebook, añade el siguiente código:

# %%
using Pkg
Pkg.activate(".")

# %% [markdown]
# Solo necesitas activar el entorno una vez por sesión.
# Después de eso, cualquier llamada a `Pkg.add(...)` instalará los paquetes únicamente en este entorno.
#
# ### Añadir y eliminar paquetes
#
# Para añadir un paquete:

# %%
using Pkg
Pkg.add("Plots")

# %% [markdown]
# Para eliminar un paquete:

# %%
Pkg.rm("Plots")

# %% [markdown]
# Para ver los paquetes instalados:

# %%
Pkg.status()

# %% [markdown]
# ### Project.toml y Manifest.toml
#
# - `Project.toml` define qué paquetes y versiones necesita tu proyecto.
# - `Manifest.toml` bloquea las versiones exactas, incluidas las dependencias de las dependencias.
#
# Para asegurarte de que los archivos de tu entorno estén actualizados, ejecuta los siguientes comandos:
#
# ```julia
#     Pkg.resolve()
#     Pkg.precompile()
# ```
#
# Estos archivos deben incluirse (commitearse) en tu repositorio de Git, especialmente `Project.toml`,  para garantizar la reproducibilidad por parte de otros usuarios.
#
# ### Consejos
#
# - Crea un entorno separado para cada proyecto.
# - Ejecuta siempre `Pkg.activate(".")` al inicio de tu notebook.
# - Ejecuta `Pkg.instantiate()` después de clonar un proyecto para instalar todas las dependencias requeridas que aparecen en `Project.toml` y `Manifest.toml`.

# %% [markdown]
# ## Integración con la línea de comandos
#
# Para ejecutar un script de Julia usando un entorno de proyecto específico, usa:
#
# ```bash
# julia --project=. script.jl
# ```
# Esto utilizará el `Project.toml` en la carpeta actual.

# %% [markdown]
# ## Integración con Jupyter
#
# Para usar tu entorno actual de Julia en notebooks de Jupyter, puedes generar un nuevo kernel de Jupyter asociado a ese entorno.
# Ejecuta lo siguiente:
#
# ```julia
#     using IJulia
#     IJulia.installkernel("Julia (ML Environment)", env=Base.current_project("ruta relativa al entorno"))
# ```
# Una vez instalado, verás un nuevo kernel llamado **'Julia (ML Environment)'** en Jupyter.
# Al seleccionarlo, se usará automáticamente el entorno especificado, sin necesidad de activarlo manualmente.

# %% [markdown]
# ## Estructura de proyecto sugerida para trabajo práctico
#
# Para garantizar claridad, mantenibilidad y reproducibilidad, se recomienda encarecidamente organizar tus proyectos del curso utilizando una estructura de carpetas bien definida.
# Aquí tienes una estructura de directorio sugerida:
#
# ```
# /ML1/
# │
# ├── environment/ ← Contiene los archivos del entorno de Julia
# │ ├── Project.toml
# │ └── Manifest.toml
# │
# ├── notebooks/ ← Notebooks de Jupyter para desarrollo y experimentación
# │ ├── 00_environment_setup.ipynb
# │ └── ... (other notebooks)
# │
# └── scripts/ ← Scripts de Julia para código reutilizable o de producción
#   └── train_model.jl
# ```
# ### ¿Por qué usar esta estructura?
#
# - **Aislamiento**: Todas las dependencias se gestionan dentro de `environment/` para evitar conflictos y garantizar la reproducibilidad.
# - **Separación de responsabilidades**: Los notebooks se usan para exploración interactiva y documentación; los scripts se utilizan para código finalizado o automatizado.
# - **Portabilidad**: Tú (y otros) podéis clonar fácilmente el repositorio, activar el entorno y reproducir los resultados.
# - **Escalabilidad**: Esta organización se adapta bien a medida que el proyecto crece.
#
# ### Consejos
#
# - Comienza siempre tus notebooks con (desde la carpeta `notebooks`):
#
#   ```julia
#       using Pkg
#       Pkg.activate("../environment")
#     ```
# -  Al ejecutar scripts desde la línea de comandos, usa (desde la carpeta `scripts`):
#   ```bash
#       julia --project=environment/ scripts/train_model.jl
#   ```
#
# - Alternativamente, para usar el entorno directamente en Jupyter, puedes generar un kernel dedicado (desde la carpeta `notebooks`):
#
# ```julia
#       using IJulia
#       IJulia.installkernel("Julia (ML Environment)", env=Base.current_project("../environment"))
#   ```
